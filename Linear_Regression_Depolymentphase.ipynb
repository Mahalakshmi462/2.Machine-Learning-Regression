# %%
import pickle #pickle is a library used to save the model

# %%
load_model=pickle.load(open("Finalized_Model_Linear.sav",'rb')) #saved model is loaded in read mode
result=load_model.predict([[0]]) # Real time testing will done by passing individual value or get input from end user and required output is stored in result variable
# Out:
# C:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result #print result
# Out:
# array([[26777.3913412]])
