# %%
import pickle

# %%
load_model=pickle.load(open("Finalized_MultiLinear.sav",'rb'))
result=load_model.predict([[178900,165432,132894,0,0]])
# Out:
# C:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[193002.18913773]])
